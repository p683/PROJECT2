# %% [markdown]
# # IMPORTING THE DATASET FROM SKLEARN

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes()                               # it is in dict format

# %%
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
diabetes.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
print(diabetes.feature_names)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
########## converting the dict format data into data frame 
# importing the libraies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.DataFrame(diabetes.data,columns=diabetes.feature_names)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9   -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# ...

# %%
df['Target']=diabetes.target
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9   -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# ...

# %%
# checking the shape of the dia dataframe
df.shape
# Out:
# (442, 11)

# %%
df.dtypes
# Out:
# age       float64
# sex       float64
# bmi       float64
# bp        float64
# s1        float64
# s2        float64
# s3        float64
# s4        float64
# s5        float64
# s6        float64
# Target    float64
# dtype: object

# %%
df.describe()                # summary of the dataset
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
### checking for the null values
df.isnull().sum()
sns.heatmap(df.isnull())

# %%
###### correlation between the featureas and outcome
##### figsize is decided
f,ax = plt.subplots(figsize=(7,5))
corr = df.corr()
### plotting the heatmap
sns.heatmap(corr,mask=np.zeros_like(corr,dtype=np.bool),cmap=sns.diverging_palette(220,10,as_cmap=True),square=True,ax=ax,annot=True)
plt.show()

# %%
### checking for outliers
plt.boxplot(df['age'])
plt.show()                                    # no outliers are present

# %%
plt.boxplot(df['s4'])
plt.show()                                    # 3 outliers are present in s4

# %%
plt.boxplot(df['Target'])
plt.show()

# %%
########## bivariate analysis
plt.scatter(df['bmi'],dia_df['Target'])
plt.show()                                             # linear relation between the two variables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d1f52d123f6f> in <module>
#       1 ########## bivariate analysis
# ----> 2 plt.scatter(df['bmi'],dia_df['Target'])
#       3 plt.show()                                             # linear relation between the two variables
#
# NameError: name 'dia_df' is not defined

# %%
plt.scatter(df['bp'],dia_df['Target'])
plt.show()

# %%
sns.pairplot(df)

# %%
######### divinding the independent and dependent variable from the df
x = df.iloc[:,0:-1].values
y = df.iloc[:,-1].values

# %%
x.shape

# %%
y.shape

# %% [markdown]
# # SPLITTING THE DATASET

# %%
# importing the library
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)

# %%
y_train = y_train.reshape(-1,1)
y_train.shape

# %%
y_test = y_test.reshape(-1,1)
y_test.shape

# %% [markdown]
# # MACHINE LEARNING MODELS

# %%
# importing the linear model
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)

# %%
y_pred = lm.predict(x_test)

# %%
plt.scatter(y_pred,y_test)
plt.show()

# %%
lm.coef_

# %%
lm.intercept_

# %%
lm.score(x,y)

# %%
from sklearn.metrics import mean_squared_error
print('error \n')
print(mean_squared_error(y_pred,y_test))

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_pred,y_test)
score

# %%
###### r2_score is always less than score value

# %% [markdown]
# # support vector machine

# %%
# importing the library
from sklearn.svm import SVR

# %%
regressor = SVR()
regressor.fit(x_train,y_train.ravel())

# %%
regressor.score(x,y)

# %%
y_pred = regressor.predict(x_test)
print(y_pred)

# %%
score = r2_score(y_pred,y_test)
score

# %%
def mean_absolute_percentage_error(x,y):
    y_true, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# %% [markdown]
# # DECISION TREE ALGORITHM

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
reg = DecisionTreeRegressor()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)

# %%
reg.score(x,y)

# %%
score = r2_score(y_pred,y_test)
score

# %% [markdown]
# # HYPERPARAMETER TUNING

# %%
# importing the grid search library
from sklearn.model_selection import GridSearchCV

# %%
parameters = [{'c':[1],'kernel':['Linear']},{'c':[1],'kernel':['rbf'],'gamma': ['auto_deprecated']}]

# %%
grid_search = GridSearchCV(estimator=regressor,param_grid=parameters,scoring='accuracy',cv=10)
